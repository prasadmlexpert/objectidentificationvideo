# %% [markdown]
# <a href="https://colab.research.google.com/github/prasadmlexpert/objectidentificationvideo/blob/main/yolov5fastapi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt  # install dependencies

# %%
import torch
import os
# Model
model = torch.hub.load('ultralytics/yolov5','custom', path= '/content/drive/.shortcut-targets-by-id/16kphvlmJsL1izzffpLfadthz0YrraYkW/ImageIdetificationProject/Project_work/data/yolov5xbdd.pt', force_reload=True)

# Images
imgs = ['/content/drive/.shortcut-targets-by-id/16kphvlmJsL1izzffpLfadthz0YrraYkW/ImageIdetificationProject/Project_work/images/10k/test/aca4b150-00000000.jpg']  # batch of images

# Inference
results = model(imgs)

# Results
results.print()
results.save()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (6.0)
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-7-30 Python-3.7.13 torch-1.12.0+cu113 CPU
#
# Fusing layers...
# Model summary: 444 layers, 86260891 parameters, 0 gradients, 204.0 GFLOPs
# Adding AutoShape...
# Saved 1 image to runs/detect/exp2
# image 1/1: 720x1280 20 cars, 4 trucks, 8 traffic signs, 8 traffic lights
# Speed: 27.3ms pre-process, 1977.3ms inference, 1.9ms NMS per image at shape (1, 3, 384, 640)
#            xmin        ymin         xmax        ymax  confidence  class  \
# 0    970.920410  372.210083  1278.186768  545.708801    0.953567      0
# 1     34.563793  367.890900   108.546265  406.846100    0.923912      0
# 2    132.515656  365.471680   200.288422  404.885193    0.916545      0
# 3    305.523529  361.443481   359.268280  397.832214    0.870461      0
# 4    103.397949  362.831207   154.164825  399.710114    0.869787      0
# 5    389.756439  355.578247   432.994171  390.136597    0.866337      0
# 6    215.339386    0.120350   258.595062   42.645889    0.859948      7
# 7    411.563690    2.826118   450.364044   60.516785    0.858898      7
# 8    331.917999    1.327221   398.845673   32.657650    0.841316      6
# 9   1181.242676  162.686035  1204.667969  198.511353    0.841019      6
# 10   561.575439  217.558365   575.756470  251.271240    0.839851      7
# 11   669.931458  219.083466   684.020935  251.894379    0.838214      7
# 12   490.482361  215.093185   505.239258  248.390472    0.823906      7
# 13   820.025940  276.334015   861.810364  294.139557    0.790475      6
# 14   518.410278  221.472641   540.258911  243.886932    0.770347      6
# 15   449.761871  355.826233   499.119232  389.695312    0.746882      0
# 16  1142.753540  169.855850  1164.189819  214.340836    0.731659      7
# 17   178.587601  352.082184   221.328873  394.412872    0.726993      0
# 18   776.398682  234.395447   792.517944  266.165710    0.697649      7
# 19   219.225830  344.120575   302.565125  399.874725    0.667175      1
# 20   790.941772  367.266296   816.171143  379.911011    0.637253      0
# 21   893.074585  328.786926   910.421265  347.057373    0.621407      6
# 22   346.005951  359.903137   373.847137  388.793823    0.597938      0
# 23   218.765228  343.883667   300.813385  400.332947    0.591404      0
# 24    55.355270  329.820404    76.554718  347.638824    0.590145      6
# 25   374.324249  331.371979   409.087250  360.920746    0.534475      1
# 26   951.423584  312.548279   964.492188  340.963562    0.532290      7
# 27   372.294830  359.052917   395.485870  383.767029    0.525949      0
# 28  1089.168213  342.072662  1122.047852  375.271759    0.507757      6
# 29   443.616608  331.703064   493.767059  383.173401    0.495286      1
# 30   275.116943  324.715820   344.760010  366.395630    0.485904      1
# 31   427.368378  356.411438   442.934296  380.290466    0.459035      0
# 32  1027.497192  365.697571  1088.237671  382.432434    0.446740      0
# 33  1004.562073  366.238922  1048.080811  382.695526    0.375773      0
# 34   358.472412  358.885620   388.174561  384.911804    0.356710      0
# 35   914.133057  364.322083   936.963623  377.058838    0.353278      0
# 36   817.650452  364.192200   847.763855  377.770813    0.340270      0
# 37   848.746521  364.314148   893.557068  376.676819    0.319334      0
# 38   292.614380  356.140747   325.907349  388.995605    0.303936      0
# 39   634.458496  346.104919   645.334717  363.413391    0.289521      6
#
#              name
# 0             car
# 1             car
# 2             car
# 3             car
# 4             car
# 5             car
# 6   traffic light
# 7   traffic light
# 8    traffic sign
# 9    traffic sign
# 10  traffic light
# 11  traffic light
# 12  traffic light
# 13   traffic sign
# 14   traffic sign
# 15            car
# 16  traffic light
# 17            car
# 18  traffic light
# 19          truck
# 20            car
# 21   traffic sign
# 22            car
# 23            car
# 24   traffic sign
# 25          truck
# 26  traffic light
# 27            car
# 28   traffic sign
# 29          truck
# 30          truck
# 31            car
# 32            car
# 33            car
# 34            car
# 35            car
# 36            car
# 37            car
# 38            car
# 39   traffic sign

# %%
import torch
import os
# Model

# Images
#imgs = ['/content/drive/.shortcut-targets-by-id/16kphvlmJsL1izzffpLfadthz0YrraYkW/ImageIdetificationProject/Project_work/images/10k/test/aca4b150-00000000.jpg']  # batch of images
def predictions(imgs):
  model = torch.hub.load('ultralytics/yolov5','custom', path= '/content/drive/.shortcut-targets-by-id/16kphvlmJsL1izzffpLfadthz0YrraYkW/ImageIdetificationProject/Project_work/data/yolov5xbdd.pt', force_reload=True)
  # Inference
  results = model(imgs)
  
  # Results
  results.print()
  results.save()  # or .show()
  results.xyxy[0]  # img1 predictions (tensor)
  results.pandas().xyxy[0]  # img1 predictions (pandas)

  return results

# %%
# !pip install fastapi nest-asyncio pyngrok uvicorn
# !pip install python-multipart
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastapi
#   Downloading fastapi-0.79.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.6 MB/s
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (1.5.5)
# Collecting pyngrok
#   Downloading pyngrok-5.1.0.tar.gz (745 kB)
#      |████████████████████████████████| 745 kB 11.8 MB/s
# Collecting uvicorn
#   Downloading uvicorn-0.18.2-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.6 MB/s
# Collecting starlette==0.19.1
#   Downloading starlette-0.19.1-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.6 MB/s
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from fastapi) (1.9.1)
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 9.4 MB/s
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.7/dist-packages (from starlette==0.19.1->fastapi) (4.1.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<5,>=3.4.0->starlette==0.19.1->fastapi) (2.10)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok) (6.0)
# Collecting h11>=0.8
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.6 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn) (7.1.2)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19007 sha256=659764e170e491503ee4300bc3339bb365c14c1e178ce0a142c46b7717113092
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# Installing collected packages: sniffio, anyio, starlette, h11, uvicorn, pyngrok, fastapi
# Successfully installed anyio-3.6.1 fastapi-0.79.0 h11-0.13.0 pyngrok-5.1.0 sniffio-1.2.0 starlette-0.19.1 uvicorn-0.18.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from python-multipart) (1.15.0)
# Building wheels for collected packages: python-multipart
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=fbe523c2007257dfb2919d1f6541df056e07a2733839166179aad7f77aece536
#   Stored in directory: /root/.cache/pip/wheels/2c/41/7c/bfd1c180534ffdcc0972f78c5758f89881602175d48a8bcd2c
# Successfully built python-multipart
# Installing collected packages: python-multipart
# Successfully installed python-multipart-0.0.5

# %%
from fastapi import FastAPI, File, UploadFile, Form
import cv2

app = FastAPI()
imgs = ['/content/drive/.shortcut-targets-by-id/16kphvlmJsL1izzffpLfadthz0YrraYkW/ImageIdetificationProject/Project_work/images/10k/test/aca4b150-00000000.jpg']  # batch of images

@app.post('/uploadfile')
def _file_upload(my_file: UploadFile = File(...)):
  print('hello')
  #1. read the image-file and view
  #img_to_detect = my_file 
  result=predictions(my_file)
  

  return {
      result
      }

#Curl command: curl -X POST http://a814-34-125-214-180.ngrok.io/uploadfile -H "accept: application/json" -H "Content-Type: multipart/form-data"  -F my_file=@untitled.png;type=image/png

# %%
import nest_asyncio
from pyngrok import ngrok
import uvicorn

ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# Opening tunnel named: http-8000-4bf06a7a-a84f-43c8-a368-6959ea7d0b3f
# t=2022-07-30T03:31:11+0000 lvl=info msg="no configuration paths supplied"
# t=2022-07-30T03:31:11+0000 lvl=info msg="using configuration at default config path" path=/root/.ngrok2/ngrok.yml
# t=2022-07-30T03:31:11+0000 lvl=info msg="open config file" path=/root/.ngrok2/ngrok.yml err=nil
# t=2022-07-30T03:31:11+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040
# t=2022-07-30T03:31:12+0000 lvl=info msg="tunnel session started" obj=tunnels.session
# t=2022-07-30T03:31:12+0000 lvl=info msg="client session established" obj=csess id=cdbf2a2c2a61
# t=2022-07-30T03:31:12+0000 lvl=info msg=start pg=/api/tunnels id=51f07b38a18ba3ad
# t=2022-07-30T03:31:12+0000 lvl=info msg=end pg=/api/tunnels id=51f07b38a18ba3ad status=200 dur=1.743175ms
# t=2022-07-30T03:31:12+0000 lvl=info msg=start pg=/api/tunnels id=d17d59afe7d199db
# t=2022-07-30T03:31:12+0000 lvl=info msg=end pg=/api/tunnels id=d17d59afe7d199db status=200 dur=104.55µs
# t=2022-07-30T03:31:12+0000 lvl=info msg=start pg=/api/tunnels id=8a405c8eda058f34
# t=2022-07-30T03:31:12+0000 lvl=info msg="started tunnel" obj=tunnels name="http-8000-4bf06a7a-a84f-43c8-a368-6959ea7d0b3f (http)" addr=http://localhost:8000 url=http://a814-34-125-214-180.ngrok.io
# t=2022-07-30T03:31:12+0000 lvl=info msg="started tunnel" obj=tunnels name=http-8000-4bf06a7a-a84f-43c8-a368-6959ea7d0b3f addr=http://localhost:8000 url=https://a814-34-125-214-180.ngrok.io
# t=2022-07-30T03:31:12+0000 lvl=info msg=end pg=/api/tunnels id=8a405c8eda058f34 status=201 dur=156.09503ms
# t=2022-07-30T03:31:12+0000 lvl=info msg=start pg="/api/tunnels/http-8000-4bf06a7a-a84f-43c8-a368-6959ea7d0b3f (http)" id=f08db93a35ac745d
# t=2022-07-30T03:31:12+0000 lvl=info msg=end pg="/api/tunnels/http-8000-4bf06a7a-a84f-43c8-a368-6959ea7d0b3f (http)" id=f08db93a35ac745d status=200 dur=138.196µs
# INFO:     Started server process [58]
# Started server process [58]
# INFO:     Waiting for application startup.
# Waiting for application startup.
# INFO:     Application startup complete.
# Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# Public URL: http://a814-34-125-214-180.ngrok.io
# t=2022-07-30T03:31:30+0000 lvl=info msg="join connections" obj=join id=9cceb7147fc5 l=127.0.0.1:8000 r=[2401:4900:1f38:4fa:1c5d:a81a:6d33:c0e5]:58013
# INFO:     2401:4900:1f38:4fa:1c5d:a81a:6d33:c0e5:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     2401:4900:1f38:4fa:1c5d:a81a:6d33:c0e5:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# t=2022-07-30T03:32:19+0000 lvl=info msg="join connections" obj=join id=5524d74ba8c7 l=127.0.0.1:8000 r=[2401:4900:1f38:4fa:1c5d:a81a:6d33:c0e5]:58017
# INFO:     2401:4900:1f38:4fa:1c5d:a81a:6d33:c0e5:0 - "POST /index HTTP/1.1" 404 Not Found
# t=2022-07-30T03:32:57+0000 lvl=info msg="join connections" obj=join id=c73c4bbb6958 l=127.0.0.1:8000 r=[2401:4900:1f38:4fa:1c5d:a81a:6d33:c0e5]:58021
# hello
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (6.0)
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-7-30 Python-3.7.13 torch-1.12.0+cu113 CPU
#
# Fusing layers...
# Model summary: 444 layers, 86260891 parameters, 0 gradients, 204.0 GFLOPs
# Adding AutoShape...
# INFO:     2401:4900:1f38:4fa:1c5d:a81a:6d33:c0e5:0 - "POST /uploadfile HTTP/1.1" 500 Internal Server Error
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/uvicorn/protocols/http/h11_impl.py", line 403, in run_asgi
#     result = await app(self.scope, self.receive, self.send)
#   File "/usr/local/lib/python3.7/dist-packages/uvicorn/middleware/proxy_headers.py", line 78, in __call__
#     return await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/applications.py", line 269, in __call__
#     await super().__call__(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/applications.py", line 124, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/usr/local/lib/python3.7/dist-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/exceptions.py", line 93, in __call__
#     raise exc
#   File "/usr/local/lib/python3.7/dist-packages/starlette/exceptions.py", line 82, in __call__
#     await self.app(scope, receive, sender)
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/middleware/asyncexitstack.py", line 21, in __call__
#     raise e
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/middleware/asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/routing.py", line 670, in __call__
#     await route.handle(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/routing.py", line 266, in handle
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/routing.py", line 65, in app
#     response = await func(request)
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/routing.py", line 228, in app
#     dependant=dependant, values=values, is_coroutine=is_coroutine
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/routing.py", line 162, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/usr/local/lib/python3.7/dist-packages/anyio/to_thread.py", line 32, in run_sync
#     func, *args, cancellable=cancellable, limiter=limiter
#   File "/usr/local/lib/python3.7/dist-packages/anyio/_backends/_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "/usr/lib/python3.7/asyncio/futures.py", line 263, in __await__
#     yield self  # This tells Task to wait for completion.
#   File "/usr/lib/python3.7/asyncio/tasks.py", line 318, in __wakeup
#     future.result()
#   File "/usr/lib/python3.7/asyncio/futures.py", line 181, in result
#     raise self._exception
#   File "/usr/local/lib/python3.7/dist-packages/anyio/_backends/_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "<ipython-input-11-b5da98362da0>", line 12, in _file_upload
#     result=predictions(my_file)
#   File "<ipython-input-10-51bcb8b29b6c>", line 10, in predictions
#     results = model(imgs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py", line 606, in forward
#     if im.shape[0] < 5:  # image in CHW
# AttributeError: 'UploadFile' object has no attribute 'shape'
# Exception in ASGI application
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/uvicorn/protocols/http/h11_impl.py", line 403, in run_asgi
#     result = await app(self.scope, self.receive, self.send)
#   File "/usr/local/lib/python3.7/dist-packages/uvicorn/middleware/proxy_headers.py", line 78, in __call__
#     return await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/applications.py", line 269, in __call__
#     await super().__call__(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/applications.py", line 124, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/usr/local/lib/python3.7/dist-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/exceptions.py", line 93, in __call__
#     raise exc
#   File "/usr/local/lib/python3.7/dist-packages/starlette/exceptions.py", line 82, in __call__
#     await self.app(scope, receive, sender)
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/middleware/asyncexitstack.py", line 21, in __call__
#     raise e
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/middleware/asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/routing.py", line 670, in __call__
#     await route.handle(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/routing.py", line 266, in handle
#     await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/routing.py", line 65, in app
#     response = await func(request)
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/routing.py", line 228, in app
#     dependant=dependant, values=values, is_coroutine=is_coroutine
#   File "/usr/local/lib/python3.7/dist-packages/fastapi/routing.py", line 162, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/usr/local/lib/python3.7/dist-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/usr/local/lib/python3.7/dist-packages/anyio/to_thread.py", line 32, in run_sync
#     func, *args, cancellable=cancellable, limiter=limiter
#   File "/usr/local/lib/python3.7/dist-packages/anyio/_backends/_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#   File "/usr/lib/python3.7/asyncio/futures.py", line 263, in __await__
#     yield self  # This tells Task to wait for completion.
#   File "/usr/lib/python3.7/asyncio/tasks.py", line 318, in __wakeup
#     future.result()
#   File "/usr/lib/python3.7/asyncio/futures.py", line 181, in result
#     raise self._exception
#   File "/usr/local/lib/python3.7/dist-packages/anyio/_backends/_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#   File "<ipython-input-11-b5da98362da0>", line 12, in _file_upload
#     result=predictions(my_file)
#   File "<ipython-input-10-51bcb8b29b6c>", line 10, in predictions
#     results = model(imgs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py", line 606, in forward
#     if im.shape[0] < 5:  # image in CHW
# AttributeError: 'UploadFile' object has no attribute 'shape'
# t=2022-07-30T03:34:04+0000 lvl=info msg="received stop request" obj=app stopReq="{err:<nil> restart:false}"
# INFO:     Shutting down
# Shutting down
# INFO:     Waiting for application shutdown.
# Waiting for application shutdown.
# INFO:     Application shutdown complete.
# Application shutdown complete.
# INFO:     Finished server process [58]
# Finished server process [58]
