# %% [markdown]
# <a href="https://colab.research.google.com/github/prasadmlexpert/objectidentificationvideo/blob/main/yolov5fastapi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt  # install dependencies

# %%
import torch
import os
# Model
model = torch.hub.load('ultralytics/yolov5','custom', path= '/content/drive/.shortcut-targets-by-id/16kphvlmJsL1izzffpLfadthz0YrraYkW/ImageIdetificationProject/Project_work/data/yolov5xbdd.pt', force_reload=True)

# Images
imgs = ['/content/drive/.shortcut-targets-by-id/16kphvlmJsL1izzffpLfadthz0YrraYkW/ImageIdetificationProject/Project_work/images/10k/test/aca4b150-00000000.jpg']  # batch of images

# Inference
results = model(imgs)

# Results
results.print()
results.save()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (6.0)
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-7-29 Python-3.7.13 torch-1.12.0+cu113 CPU
#
# Fusing layers...
# Model summary: 444 layers, 86260891 parameters, 0 gradients, 204.0 GFLOPs
# Adding AutoShape...
# Saved 1 image to runs/detect/exp
# image 1/1: 720x1280 20 cars, 4 trucks, 7 traffic signs, 8 traffic lights, 1 pedestrian
# Speed: 521.8ms pre-process, 2280.0ms inference, 29.1ms NMS per image at shape (1, 3, 384, 640)
#            xmin        ymin         xmax        ymax  confidence  class  \
# 0    972.730286  369.554657  1280.000000  548.759888    0.937545      0
# 1    132.627533  365.344177   199.760071  404.557617    0.900962      0
# 2     33.535362  368.254669   108.247810  405.697906    0.894019      0
# 3    307.050232  361.742645   357.956543  397.530060    0.872946      0
# 4    388.781616  355.669800   433.516235  390.377808    0.854006      0
# 5    102.764641  363.061188   152.555237  399.760590    0.849511      0
# 6    669.156616  220.700775   683.700562  252.324677    0.807132      7
# 7    410.868347    2.391312   450.204712   61.470322    0.802425      7
# 8    561.439514  217.516632   576.381653  250.533783    0.801205      7
# 9    820.242676  275.004150   863.266235  295.301514    0.793191      6
# 10  1181.737427  163.347733  1204.982056  198.117416    0.792433      6
# 11   215.246094    0.490374   258.530945   42.211891    0.789253      7
# 12   490.081848  215.589447   505.413269  248.460663    0.750998      7
# 13   518.341492  221.618225   540.807434  244.815674    0.729484      6
# 14   776.244507  235.509491   791.723999  265.546844    0.727142      7
# 15   220.019058  342.994812   299.972412  400.357605    0.710671      0
# 16   178.911606  351.470947   222.835373  391.062256    0.705078      0
# 17   343.643829  358.197479   374.174347  389.415253    0.645774      0
# 18   332.845978    3.283085   397.446808   32.429256    0.640648      6
# 19   893.513733  328.545685   910.015320  346.299774    0.614077      6
# 20    55.802261  329.566528    75.726654  349.270752    0.599390      6
# 21   444.482971  332.500244   497.165955  385.178467    0.597399      1
# 22   791.537781  367.073181   815.710266  379.726379    0.572873      0
# 23   218.292526  344.041473   300.404724  399.820953    0.567427      1
# 24  1143.163086  171.085419  1164.261475  213.183380    0.552715      7
# 25  1089.510010  342.306671  1122.188232  376.007904    0.525101      6
# 26   375.748627  331.370514   409.890167  371.212494    0.516858      1
# 27   952.657593  312.740112   964.641479  336.636902    0.516085      7
# 28  1024.927490  365.020233  1095.135254  382.702057    0.511770      0
# 29   452.197998  353.825470   499.552368  390.341400    0.505977      0
# 30   427.879761  356.113403   444.536743  380.109924    0.460813      0
# 31   363.842163  359.030243   387.231140  384.677765    0.432959      0
# 32   273.450562  323.200439   346.655640  378.759888    0.407819      1
# 33   818.545715  363.976013   850.648010  377.326294    0.405660      0
# 34   914.168945  364.078766   937.043091  376.600006    0.352548      0
# 35   372.534180  349.684143   400.342712  383.891296    0.351614      0
# 36   296.080627  358.570862   319.882019  387.845032    0.336875      0
# 37   853.362427  364.255554   892.927979  376.086792    0.305647      0
# 38  1002.324890  367.278076  1031.324341  382.632446    0.273759      0
# 39   631.430481  343.851105   645.398743  374.319427    0.269938      9
#
#              name
# 0             car
# 1             car
# 2             car
# 3             car
# 4             car
# 5             car
# 6   traffic light
# 7   traffic light
# 8   traffic light
# 9    traffic sign
# 10   traffic sign
# 11  traffic light
# 12  traffic light
# 13   traffic sign
# 14  traffic light
# 15            car
# 16            car
# 17            car
# 18   traffic sign
# 19   traffic sign
# 20   traffic sign
# 21          truck
# 22            car
# 23          truck
# 24  traffic light
# 25   traffic sign
# 26          truck
# 27  traffic light
# 28            car
# 29            car
# 30            car
# 31            car
# 32          truck
# 33            car
# 34            car
# 35            car
# 36            car
# 37            car
# 38            car
# 39     pedestrian
